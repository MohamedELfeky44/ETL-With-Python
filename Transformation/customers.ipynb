# %%
import pandas as pd

customers = pd.read_csv('../staging_1/customers.csv')
customers
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks         UNKNOWN
# 1               2       Kasha      Todd         UNKNOWN
# 2               3      Tameka    Fisher         UNKNOWN
# 3               4       Daryl    Spence         UNKNOWN
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison         UNKNOWN
# 1441         1442      Cassie     Cline         UNKNOWN
# 1442         1443      Lezlie      Lamb         UNKNOWN
# 1443         1444      Ivette     Estes         UNKNOWN
# 1444         1445       Ester   Acevedo         UNKNOWN
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
stores = pd.read_csv('../staging_1/stores.csv')
stores
# Out:
#    store_id        store_name           phone               email  \
# 0         1  Santa Cruz Bikes  (831) 476-4321             UNKWOWN
# 1         2     Baldwin Bikes  (516) 379-8888  baldwin@bikes.shop
# 2         3     Rowlett Bikes  (972) 530-5555  rowlett@bikes.shop
#
#                 street        city state zip_code                   Timestamp
# 0   3700 Portola Drive  Santa Cruz    CA  UNKWOWN  2024-05-02 00:55:47.044600
# 1   4200 Chestnut Lane     Baldwin    NY  11432.0  2024-05-02 00:55:47.044600
# 2  8000 Fairway Avenue     Rowlett    TX  75088.0  2024-05-02 00:55:47.044600

# %%
cities = stores.city.unique()
cities
# Out:
# array(['Santa Cruz', 'Baldwin', 'Rowlett'], dtype=object)

# %%
customers.local = customers.city.isin(cities)
customers
# Out:
# C:\Users\M.El-fiqy\AppData\Local\Temp\ipykernel_11312\533515486.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   customers.local = customers.city.isin(cities)
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks         UNKNOWN
# 1               2       Kasha      Todd         UNKNOWN
# 2               3      Tameka    Fisher         UNKNOWN
# 3               4       Daryl    Spence         UNKNOWN
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison         UNKNOWN
# 1441         1442      Cassie     Cline         UNKNOWN
# 1442         1443      Lezlie      Lamb         UNKNOWN
# 1443         1444      Ivette     Estes         UNKNOWN
# 1444         1445       Ester   Acevedo         UNKNOWN
#
# ...

# %%
import os 
save_directory = "../Staging_2"
csv_file_path1 = os.path.join(save_directory, "customers.csv")
df.to_csv(csv_file_path1, index=False)
