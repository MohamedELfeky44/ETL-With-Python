# %%
import pandas as pd 

order_items = pd.read_csv('../staging_1/order_items.csv')
order_items
# Out:
#       order_id   item_id  product_id  quantity  list_price  discount  \
# 0          1.0         1        20.0       1.0      599.99      0.20
# 1          1.0         2         8.0       2.0     1799.99      0.07
# 2          1.0         3        10.0       2.0     1549.00      0.05
# 3          1.0         4        16.0       2.0      599.99      0.05
# 4          1.0         5         4.0       1.0     2899.99      0.20
# ...        ...       ...         ...       ...         ...       ...
# 4725    1615.0         9       182.0       1.0     2499.99      0.20
# 4726    1612.0  'sz258l'       289.0       2.0      319.99      0.05
# 4727    1612.0  'sz756l'       101.0       2.0      339.99      0.20
# 4728    1612.0  'sz758k'       293.0       2.0      319.99      0.07
# 4729    1612.0  'sz758l'        60.0       1.0     1559.99      0.10
#
#                        Timestamp
# 0     2024-05-02 01:40:16.045001
# 1     2024-05-02 01:40:16.045001
# 2     2024-05-02 01:40:16.045001
# ...

# %%
exchange = pd.read_csv('../Landing/exchange.csv')
exchange
# Out:
#              timestamp      EGP        timestamp_extraction
# 0  2024-05-02 00:00:29  47.6735  2024-05-02 03:06:55.420804

# %%
order_items['EGP Rate'] =exchange.EGP
order_items['EGP Rate'] = order_items['EGP Rate'].fillna(method='ffill')
order_items
# Out:
# C:\Users\M.El-fiqy\AppData\Local\Temp\ipykernel_19812\2571017940.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   order_items['EGP Rate'] = order_items['EGP Rate'].fillna(method='ffill')
#       order_id   item_id  product_id  quantity  list_price  discount  \
# 0          1.0         1        20.0       1.0      599.99      0.20
# 1          1.0         2         8.0       2.0     1799.99      0.07
# 2          1.0         3        10.0       2.0     1549.00      0.05
# 3          1.0         4        16.0       2.0      599.99      0.05
# 4          1.0         5         4.0       1.0     2899.99      0.20
# ...        ...       ...         ...       ...         ...       ...
# 4725    1615.0         9       182.0       1.0     2499.99      0.20
# 4726    1612.0  'sz258l'       289.0       2.0      319.99      0.05
# 4727    1612.0  'sz756l'       101.0       2.0      339.99      0.20
# ...

# %%
order_items['list_price_egp'] = order_items['list_price'] * order_items['EGP Rate']
order_items
# Out:
#       order_id   item_id  product_id  quantity  list_price  discount  \
# 0          1.0         1        20.0       1.0      599.99      0.20
# 1          1.0         2         8.0       2.0     1799.99      0.07
# 2          1.0         3        10.0       2.0     1549.00      0.05
# 3          1.0         4        16.0       2.0      599.99      0.05
# 4          1.0         5         4.0       1.0     2899.99      0.20
# ...        ...       ...         ...       ...         ...       ...
# 4725    1615.0         9       182.0       1.0     2499.99      0.20
# 4726    1612.0  'sz258l'       289.0       2.0      319.99      0.05
# 4727    1612.0  'sz756l'       101.0       2.0      339.99      0.20
# 4728    1612.0  'sz758k'       293.0       2.0      319.99      0.07
# 4729    1612.0  'sz758l'        60.0       1.0     1559.99      0.10
#
#                        Timestamp  EGP Rate  list_price_egp
# 0     2024-05-02 01:40:16.045001   47.6735    28603.623265
# ...

# %%
import os 
save_directory = "../staging_2"
csv_file_path = os.path.join(save_directory, "order_items.csv")
order_items.to_csv(csv_file_path, index=False)
