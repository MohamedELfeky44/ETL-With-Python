# %%
import pandas as pd 
file_path = '../Landing/orders.csv'
df = pd.read_csv(file_path)
df
# Out:
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  2016-01-01    2016-01-03
# 1            2         1212             4  2016-01-01    2016-01-04
# 2            3          523             4  2016-01-02    2016-01-05
# 3            4          175             4  2016-01-03    2016-01-04
# 4            5         1324             4  2016-01-03    2016-01-06
# ...        ...          ...           ...         ...           ...
# 1610      1611            6             3  2018-09-06    2018-09-06
# 1611      1612            3             3  2018-10-21    2018-10-21
# 1612      1613            1             3  2018-11-18    2018-11-18
# 1613      1614          135             3  2018-11-28    2018-11-28
# 1614      1615          136             3  2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id                   Timestamp
# 0      2016-01-03         1         2  2024-05-02 00:55:47.043606
# ...

# %%
#check for nulls
df.isnull().sum()
# Out:
# order_id           0
# customer_id        0
# order_status       0
# order_date         0
# required_date      0
# shipped_date     170
# store_id           0
# staff_id           0
# Timestamp          0
# dtype: int64

# %%
df.fillna('UNKNOWN',inplace =True)
df.isnull().sum()
# Out:
# order_id         0
# customer_id      0
# order_status     0
# order_date       0
# required_date    0
# shipped_date     0
# store_id         0
# staff_id         0
# Timestamp        0
# dtype: int64

# %%
df.fillna('UNKWOWN',inplace = True)
df.isnull().sum()
# Out:
# order_id         0
# customer_id      0
# order_status     0
# order_date       0
# required_date    0
# shipped_date     0
# store_id         0
# staff_id         0
# Timestamp        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Handel Date Range to be between 2000 and 2024
df['order_date'] = pd.to_datetime(df['order_date'],errors='coerce')
df['order_year'] = df['order_date'].dt.year
df
# Out:
#       order_id  customer_id  order_status order_date required_date  \
# 0            1          259             4 2016-01-01    2016-01-03
# 1            2         1212             4 2016-01-01    2016-01-04
# 2            3          523             4 2016-01-02    2016-01-05
# 3            4          175             4 2016-01-03    2016-01-04
# 4            5         1324             4 2016-01-03    2016-01-06
# ...        ...          ...           ...        ...           ...
# 1610      1611            6             3 2018-09-06    2018-09-06
# 1611      1612            3             3 2018-10-21    2018-10-21
# 1612      1613            1             3 2018-11-18    2018-11-18
# 1613      1614          135             3 2018-11-28    2018-11-28
# 1614      1615          136             3 2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id                   Timestamp  order_year
# 0      2016-01-03         1         2  2024-05-02 00:55:47.043606      2016.0
# ...

# %%
df = df[(df['order_year'] >= 2000.0) & (df['order_year'] <= 2024.0) ]
df
# Out:
#       order_id  customer_id  order_status order_date required_date  \
# 0            1          259             4 2016-01-01    2016-01-03
# 1            2         1212             4 2016-01-01    2016-01-04
# 2            3          523             4 2016-01-02    2016-01-05
# 3            4          175             4 2016-01-03    2016-01-04
# 4            5         1324             4 2016-01-03    2016-01-06
# ...        ...          ...           ...        ...           ...
# 1610      1611            6             3 2018-09-06    2018-09-06
# 1611      1612            3             3 2018-10-21    2018-10-21
# 1612      1613            1             3 2018-11-18    2018-11-18
# 1613      1614          135             3 2018-11-28    2018-11-28
# 1614      1615          136             3 2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id                   Timestamp  order_year
# 0      2016-01-03         1         2  2024-05-02 00:55:47.043606      2016.0
# ...

# %% [markdown]
# ### since there are no duplicates and we handeled nulls we can write the file

# %%
import os

# Define the file path
output_directory = "../staging_1"
output_file_path = os.path.join(output_directory, "orders.csv")

# Write the DataFrame to CSV
df.to_csv(output_file_path, index=False)
